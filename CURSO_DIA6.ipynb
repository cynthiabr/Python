# %% [markdown]
# #DIA 6
# ##Programación Orientada a Objetos
#
# ##Temario
# - 1.- ¿Qué es POO?
# - 2.- Entidades: Clases y Objetos
# - 3.- self, _init_ y el ciclo de vida de un objeto
# - 4.- Atributos: De instancia vs de clase
# - 5.- Método: instsancia, clase
# - 6.- Encapsulamiento y propiedades
# - 7.- Herencia y Abstracción
# - 8.- Polimorfismo
# - 9.- Composición vs Herencia

# %% [markdown]
# ## 1.- ¿Qué es POO y por qué usarla?
# 1. Clases (Los Molde)
#
# Una clase es como el model o plano para crear algo
#
# 2. Objeto(Lass creaciones)
#
# Un objeto es una instancia real tangible creada a partir de una clase
#
# ## 2.- Entidades: Clases y Objetos

# %%
class Perro: #Creaste tu clase
  def ladrar(self): #Método
    print("Guau!")

mi_perro = Perro() #Creación de tu Objeto
mi_perro.ladrar()
# Out:
# Guau!

# %% [markdown]
# ## 3.- self, _init_ y el ciclo de vida de un objeto

# %%
class Perro:
#self es la referencia a la instancia actual, _init_
  def __init__(self, nombre, edad): #Construcción
    self.nombre = nombre
    self.edad = edad
  def presentarse(self):
    print(f"Soy{self.nombre} y tengo {self.edad} años")
naylah = Perro("Naylah", 5)
naylah.presentarse()
# Out:
# SoyNaylah y tengo 5 años

# %% [markdown]
# #4.- Atributos: de instancia vs de clase

# %%
class Perro:
  patas = 4
  especie = "Caninis Familiaris" #Atributos de clase
  def __init__(self,nombre):
    self.nombre = nombre #Atributos de instancia
p1 = Perro("Firulais")
p2 = Perro("Bobby")
print(p1.especie)
print(p2.especie)
print("-----------")
p2.especie = "Gato"
print(p1.especie)
print(p2.especie) #cambio el atributo de la clase ESPECIALMENTE para p2
# Out:
# Caninis Familiaris
# Caninis Familiaris
# -----------
# Caninis Familiaris
# Gato

# %%
print(p1.__dict__)
print(p2.__dict__)
# Out:
# {'nombre': 'Firulais'}
# {'nombre': 'Bobby', 'especie': 'Gato'}

# %% [markdown]
# #Métodos: De instancia, clase
# Un método de instancia es una función definida dentro de una clase que:
# - Opera sobre un objeto concreto (una instancia)
# - Puede acceder y modificar los atricutos de ese objeto
# - Recibe como primer parámetro a self

# %%
# (ya lo hemos usado)
class tuClase:
  def metodo(self):
    pass

#método -> método de instancia
#self -> referencia al objeto que llama al método

# %%
#Calculadora:
class Calculadora:
  def __init__(self,num1,num2):
    self.num1 = num1
    self.num2 = num2
  def sumar(self):
    print(self.num1 + self.num2)
  def resta(self):
    print(self.num1 - self.num2)
  def multiplicar(self):
    print(self.num1 * self.num2)
  def dividir(self):
    if self.num2 == 0:
      print("Número no divisible")
    else:
      print(self.num1/self.num2)
Calculadora = Calculadora(7,0)
Calculadora.dividir()
Calculadora.sumar()
Calculadora.multiplicar()
# Out:
# Número no divisible
# 7
# 0

# %%
#EJERCICIO, CREAR UNA CLASE ANIMAL, donde tenga una instancia (constructor) de por lo menos 3 variables con 1 método y crea 4 objetos
class Animal: #1.- Clase
  def __init__(self, nombre, especie, patas, comida_favorita, sonido): #2.- Instancia
    self.nombre = nombre #3.- variables
    self.especie = especie
    self.patas = patas
    self.comida_favorita = comida_favorita
    self.sonido = sonido
  def hacer_sonido(self): #4.- Método
    print(self.sonido)

gato = Animal("Rayiras", "Gato", 4, "Carne de res", "miau") #4 Objetos
perro = Animal("Mechas", "Perro", 4, "Pollito Asado", "woof")
pajaro = Animal("Paco", "Perico", 2, "Semillas", "pipipi")
vaca = Animal("Manchas", "Vaca", 4, "Pasto", "muuu")

vaca.hacer_sonido()
gato.nombre = "Juan"
gato.nombre
# Out:
# muuu
# 'Juan'

# %% [markdown]
# #6.- Encapsulamiento y propiedades

# %%
class Cuenta:
  def __init__(self,saldo):
    self.__saldo = saldo #Privada
# Sirve para proteger los datos internos de un objeto y controlar como se leen y modifican
cuenta = Cuenta(1000)
cuenta.Cuenta = 2000 #si yedes editarlo
#print(uenta.__saldo) #Error : no se puede acceder directamente

# %%
# Getters y Setters
class Cuenta:
  def __init__(self,saldo):
    self.__saldo = saldo
  @property
  def saldo(self): #Getter
    #Permite leer el valor de __saldo usando c.saldo
    return self.__saldo
  @saldo.setter #Setter
  def saldo(self, valor):
    #se ejecuta cuando hacemos c.saldo = valor
    self.__saldo = valor
c = Cuenta(300)
print(c.saldo)
c.saldo = 4000
# Out:
# 300

# %% [markdown]
# ##7.- Herencia y  Abstracción

# %%
#Herencia
class Vehículo:
  def __init__(self , marca, modelo):
    self.marca = marca
    self.modelo = modelo
  def descipcion(self):
    return f"{self.marca}:{self.modelo}"
  def mover(self):
    return "El vehículo se esta moviendo..."
#------------------------------------------------
class Coche(Vehículo): #subclase 1(Clase hija)
  def mover(self):
    return "El coche esta conduciendo"
#-------------------------------------------------
class Moto(Vehículo):
  def mover(self):
    return "La moto avanza sobre ruedas"

coche = Coche("Toyota", "Corolla")
coche2 = Vehículo("BYD", "Dolphin")
moto = Moto("Yamaha", "R6")
print(coche.mover())
print(coche2.mover())
print(moto.mover())
#aunque no volvimos a declarar el método dentro de descripción, podemos seguir usandolo ya que lo heredo del padreprint(coche.mover())print....
# Out:
# El coche esta conduciendo
# El vehículo se esta moviendo...
# La moto avanza sobre ruedas

# %%
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad
  def presentarse(self):
    print(f"Hola, soy {self.nombre} y tengo {self.edad} años")
class Estudiante(Persona):
  def __init__(self,nombre,edad,carrera):
    super().__init__(nombre, edad)
    self.carrera = carrera
  def presentarse(self):
    super().presentarse()
    print(f"Estudio la carrera de {self.carrera}")
#Reutiliza el constructor de la clase padre (lo cual evita duplicar el código)
#Ejecuta el comportamiento base y luego lo extiende
est = Estudiante("Ana", 21, "Programación")
est.presentarse()
# Out:
# Hola, soy Ana y tengo 21 años
# Estudio la carrera de Programación

# %%
#Abstracción
class Animal:
  def hablar(self):
    raise NotImplementedError
class Gato(Animal):
  def hablar(self):
    return "miau"

# %% [markdown]
# ##Polimorfismo
# (Justo ya lo implementamos) El polimorfismo significa que diferentes objetos pueden responder al mismo mensaje (método) de forma distinta, siempre y cuando compartan una interfaz común.

# %% [markdown]
# #Compiscion HAS-A
# Por que se llama composición? Porque estas componiendo (armando) un objeto grande usando otros objetos. Es un principio de POO donde:
# - Una clase NO hereda de otra, si no que contiene un objeto de esa otra clase

# %%
class Banco:
  def __init__(self,dinero):
    self.dinero = dinero
  def ver_total(self):
    print(f"Total en la cuenta: ${self.dinero}")
class Persona:
  def __init__(self,cuenta:Banco): #Indica que este parámetro debería ser una instancia de la clase Banco
    self.cuenta = cuenta #Persona TIENE un banco, no hereda de él

# %% [markdown]
# ##9.- Composición vs Herencia
# Esto se va a responder con pura:
# No signifia que alguna sea mejor que otra simplemente que a veces una te puede convenir más que otra:
#
# Herencia: un gato ES un animal (no "Un gato TIENE un animal")
# Composición: Una persona TIENE una cuenta (no "Una persona ES un banco")

# %%
# Clase base
class Vehiculo:
    def __init__(self, marca):
        self.marca = marca

    def mover(self):
        raise NotImplementedError("Este método DEBE ser implementado.")


# Clase Motor (Composición)
class Motor:
    def __init__(self, caballos):
        self.caballos = caballos

    def potencia(self):
        return f"{self.caballos} HP"


# Coche usa herencia + composición + polimorfismo
class Coche(Vehiculo):
    def __init__(self, marca, caballos):
        super().__init__(marca)
        self.motor = Motor(caballos)  # COMPOSICIÓN

    def mover(self):  # POLIMORFISMO
        return f"El coche {self.marca} avanza con motor de {self.motor.potencia()}"


# Moto usa herencia + composición + polimorfismo
class Moto(Vehiculo):
    def __init__(self, marca, caballos):
        super().__init__(marca)
        self.motor = Motor(caballos)  # COMPOSICIÓN

    def mover(self):  # POLIMORFISMO
        return f"La moto {self.marca} acelera con motor de {self.motor.potencia()}"


# Bicicleta no tiene motor
class Bicicleta(Vehiculo):
    def mover(self):  # POLIMORFISMO
        return f"La bicicleta {self.marca} avanza con pedaleo humano"


# Función que prueba el polimorfismo
def probar_vehiculos(lista):
    for v in lista:
        print(v.mover())


# Lista de vehículos (sí, se pueden mezclar clases)
vehiculos = [
    Coche("Toyota", 150),
    Moto("Yamaha", 90),
    Bicicleta("Trek")
]

probar_vehiculos(vehiculos)
# Out:
# El coche Toyota avanza con motor de 150 HP
# La moto Yamaha acelera con motor de 90 HP
# La bicicleta Trek avanza con pedaleo humano
